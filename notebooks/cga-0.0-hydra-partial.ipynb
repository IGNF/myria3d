# %%
# app.py
from omegaconf import DictConfig, OmegaConf

import hydra
from hydra.utils import instantiate

# OmegaConf.register_new_resolver("get_method", hydra.utils.get_method)

@hydra.main(config_path=".", config_name="cga-0.0-hydra-partial.yaml")
def my_app(cfg: DictConfig) -> None:
    opt = instantiate(cfg)
    # print(OmegaConf.to_yaml(cfg))
    print(opt)

my_app()
# Out:
# usage: ipykernel_launcher.py [--help] [--hydra-help] [--version]
#                              [--cfg {job,hydra,all}] [--resolve]
#                              [--package PACKAGE] [--run] [--multirun]
#                              [--shell-completion] [--config-path CONFIG_PATH]
#                              [--config-name CONFIG_NAME]
#                              [--config-dir CONFIG_DIR]
#                              [--info [{all,config,defaults,defaults-tree,plugins,searchpath}]]
#                              [overrides ...]
# ipykernel_launcher.py: error: argument --shell-completion/-sc: ignored explicit argument '9003'
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py", line 1851, in parse_known_args
#     namespace, args = self._parse_known_args(args, namespace)
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py", line 2060, in _parse_known_args
#     start_index = consume_optional(start_index)
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py", line 1982, in consume_optional
#     raise ArgumentError(action, msg % explicit_arg)
# argparse.ArgumentError: argument --shell-completion/-sc: ignored explicit argument '9003'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_70030/2977969889.py", line 15, in <module>
#     my_app()
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/hydra/main.py", line 48, in decorated_main
#     _run_hydra(
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/hydra/_internal/utils.py", line 309, in _run_hydra
#     args = args_parser.parse_args()
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py", line 1818, in parse_args
#     args, argv = self.parse_known_args(args, namespace)
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py", line 1854, in parse_known_args
#     self.error(str(err))
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py", line 2575, in error
#     self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py", line 2562, in exit
#     _sys.exit(status)
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/inspect.py", line 1529, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py in parse_known_args(self, args, namespace)
#    1850             try:
# -> 1851                 namespace, args = self._parse_known_args(args, namespace)
#    1852             except ArgumentError:
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py in _parse_known_args(self, arg_strings, namespace)
#    2059             # consume the next optional and any arguments for it
# -> 2060             start_index = consume_optional(start_index)
#    2061
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py in consume_optional(start_index)
#    1981                         msg = _('ignored explicit argument %r')
# -> 1982                         raise ArgumentError(action, msg % explicit_arg)
#    1983
#
# ArgumentError: argument --shell-completion/-sc: ignored explicit argument '9003'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_70030/2977969889.py in <module>
#      14
# ---> 15 my_app()
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/hydra/main.py in decorated_main(cfg_passthrough)
#      47                 # multiple times (--multirun)
# ---> 48                 _run_hydra(
#      49                     args_parser=args,
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/hydra/_internal/utils.py in _run_hydra(args_parser, task_function, config_path, config_name)
#     308
# --> 309     args = args_parser.parse_args()
#     310     if args.config_name is not None:
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py in parse_args(self, args, namespace)
#    1817     def parse_args(self, args=None, namespace=None):
# -> 1818         args, argv = self.parse_known_args(args, namespace)
#    1819         if argv:
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py in parse_known_args(self, args, namespace)
#    1853                 err = _sys.exc_info()[1]
# -> 1854                 self.error(str(err))
#    1855         else:
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py in error(self, message)
#    2574         args = {'prog': self.prog, 'message': message}
# -> 2575         self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/argparse.py in exit(self, status, message)
#    2561             self._print_message(message, _sys.stderr)
# -> 2562         _sys.exit(status)
#    2563
#
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2068                     stb = ['An exception has occurred, use %tb to see '
#    2069                            'the full traceback.\n']
# -> 2070                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2071                                                                      value))
#    2072                 else:
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     627             chained_exceptions_tb_offset = 0
#     628             out_list = (
# --> 629                 self.structured_traceback(
#     630                     etype, evalue, (etb, chained_exc_ids),
#     631                     chained_exceptions_tb_offset, context)
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /var/data/cgaydon/anaconda3/envs/validation_module/lib/python3.9/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
